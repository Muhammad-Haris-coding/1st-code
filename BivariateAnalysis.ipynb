# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Haris-coding/1st-code/blob/main/BivariateAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=sns.load_dataset('tips')

# %%
titanic=pd.read_csv('/content/titanicDataset.csv')

# %%
flights=sns.load_dataset('flights')

# %%
iris=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Numerical vs NUmerical data analysis

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'] , hue=df['sex'] ,style=df['day'],size=df['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Numerical vs catagorical data analysis

# %% [markdown]
# **Bar Plot**

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.barplot(x=titanic['Pclass'].astype('str'), y=titanic['Age'], hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ### **Boxplot**

# %%
sns.boxplot(x=titanic['Sex'] , y=titanic['Age'], hue=titanic['Pclass'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ### **Distplot**

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'] , hist=False)
sns.distplot(titanic[titanic['Survived']==1]['Age'], hist=False)
# Out:
# /tmp/ipython-input-1521090051.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'] , hist=False)
# /tmp/ipython-input-1521090051.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# **heat map**

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'] , titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# ### Clustermap

# %%
pd.crosstab(titanic['Parch'], titanic['Survived'])
# Out:
# Survived    0   1
# Parch
# 0         225  99
# 1          24  28
# 2          13  20
# 3           1   2
# 4           0   2
# 5           1   0
# 6           1   0
# 9           1   1

# %%
sns.clustermap(pd.crosstab(titanic['Parch'], titanic['Survived']))

# %% [markdown]
# ## line **plot**
#   it is used when during numerical and numerical bivariate analysis but when the x axis is time base like day , month , date etc

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
yearwise=flights.groupby('year')['passengers'].sum()

# %%
sns.lineplot(x=flights['year'], y=flights['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### **pair plot**
# pair plot is used between the numerical numerical data columns . it give the complete plot of each numerical coulmn with each other numerical columns

# %%
sns.pairplot(iris ,hue='species')
